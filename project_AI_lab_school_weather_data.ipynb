# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierSoni/project-ai-lab-school/blob/main/project_AI_lab_school_weather_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
w1=pd.read_csv('/content/drive/MyDrive/weather_data/weather01.txt',sep= '\s+')
w1
# Out:
#        X  year  month            measure    X1   X2
# 1      1  2014     12   Max.TemperatureF    64   42
# 2      2  2014     12  Mean.TemperatureF    52   38
# 3      3  2014     12   Min.TemperatureF    39   33
# 4      4  2014     12     Max.Dew.PointF    46   40
# 5      5  2014     12     MeanDew.PointF    40   27
# ..   ...   ...    ...                ...   ...  ...
# 282  282  2015     12  Max.Gust.SpeedMPH    17  NaN
# 283  283  2015     12    PrecipitationIn  0.14  NaN
# 284  284  2015     12         CloudCover     7  NaN
# 285  285  2015     12             Events  Rain  NaN
# 286  286  2015     12     WindDirDegrees   109  NaN
#
# [286 rows x 6 columns]

# %%
w2=pd.read_csv('/content/drive/MyDrive/weather_data/weather02.txt',sep= '\s+')
w3=pd.read_csv('/content/drive/MyDrive/weather_data/weather03.txt',sep= '\s+')
w4=pd.read_csv('/content/drive/MyDrive/weather_data/weather04.txt',sep= '\s+')
w5=pd.read_csv('/content/drive/MyDrive/weather_data/weather05.txt',sep= '\s+')
w6=pd.read_csv('/content/drive/MyDrive/weather_data/weather06.txt',sep= '\s+')

# %%
w2
# Out:
#       X3   X4   X5   X6   X7
# 1     51   43   42   45   38
# 2     44   37   34   42   30
# 3     37   30   26   38   21
# 4     49   24   37   45   36
# 5     42   21   25   40   20
# ..   ...  ...  ...  ...  ...
# 282  NaN  NaN  NaN  NaN  NaN
# 283  NaN  NaN  NaN  NaN  NaN
# 284  NaN  NaN  NaN  NaN  NaN
# 285  NaN  NaN  NaN  NaN  NaN
# 286  NaN  NaN  NaN  NaN  NaN
#
# [286 rows x 5 columns]

# %%
weather=pd.concat([w1,w2,w3,w4,w5,w6],axis='columns')
weather
# Out:
#        X  year  month            measure    X1   X2   X3   X4   X5   X6  ...  \
# 1      1  2014     12   Max.TemperatureF    64   42   51   43   42   45  ...
# 2      2  2014     12  Mean.TemperatureF    52   38   44   37   34   42  ...
# 3      3  2014     12   Min.TemperatureF    39   33   37   30   26   38  ...
# 4      4  2014     12     Max.Dew.PointF    46   40   49   24   37   45  ...
# 5      5  2014     12     MeanDew.PointF    40   27   42   21   25   40  ...
# ..   ...   ...    ...                ...   ...  ...  ...  ...  ...  ...  ...
# 282  282  2015     12  Max.Gust.SpeedMPH    17  NaN  NaN  NaN  NaN  NaN  ...
# 283  283  2015     12    PrecipitationIn  0.14  NaN  NaN  NaN  NaN  NaN  ...
# 284  284  2015     12         CloudCover     7  NaN  NaN  NaN  NaN  NaN  ...
# 285  285  2015     12             Events  Rain  NaN  NaN  NaN  NaN  NaN  ...
# 286  286  2015     12     WindDirDegrees   109  NaN  NaN  NaN  NaN  NaN  ...
#
# ...

# %%
weather.drop(columns='X', inplace=True)

# %%
weatherm=weather.melt(id_vars=['year','month','measure'])
weatherm
# Out:
#       year  month            measure variable value
# 0     2014     12   Max.TemperatureF       X1    64
# 1     2014     12  Mean.TemperatureF       X1    52
# 2     2014     12   Min.TemperatureF       X1    39
# 3     2014     12     Max.Dew.PointF       X1    46
# 4     2014     12     MeanDew.PointF       X1    40
# ...    ...    ...                ...      ...   ...
# 8861  2015     12  Max.Gust.SpeedMPH      X31   NaN
# 8862  2015     12    PrecipitationIn      X31   NaN
# 8863  2015     12         CloudCover      X31   NaN
# 8864  2015     12             Events      X31   NaN
# 8865  2015     12     WindDirDegrees      X31   NaN
#
# [8866 rows x 5 columns]

# %%
weatherm=weatherm.rename(columns={'variable':'day'})
weatherm
# Out:
#       year  month            measure  day value
# 0     2014     12   Max.TemperatureF   X1    64
# 1     2014     12  Mean.TemperatureF   X1    52
# 2     2014     12   Min.TemperatureF   X1    39
# 3     2014     12     Max.Dew.PointF   X1    46
# 4     2014     12     MeanDew.PointF   X1    40
# ...    ...    ...                ...  ...   ...
# 8861  2015     12  Max.Gust.SpeedMPH  X31   NaN
# 8862  2015     12    PrecipitationIn  X31   NaN
# 8863  2015     12         CloudCover  X31   NaN
# 8864  2015     12             Events  X31   NaN
# 8865  2015     12     WindDirDegrees  X31   NaN
#
# [8866 rows x 5 columns]

# %%
weatherm.day=weatherm.day.str.replace('X','').astype(int)
weatherm
# Out:
#       year  month            measure  day value
# 0     2014     12   Max.TemperatureF    1    64
# 1     2014     12  Mean.TemperatureF    1    52
# 2     2014     12   Min.TemperatureF    1    39
# 3     2014     12     Max.Dew.PointF    1    46
# 4     2014     12     MeanDew.PointF    1    40
# ...    ...    ...                ...  ...   ...
# 8861  2015     12  Max.Gust.SpeedMPH   31   NaN
# 8862  2015     12    PrecipitationIn   31   NaN
# 8863  2015     12         CloudCover   31   NaN
# 8864  2015     12             Events   31   NaN
# 8865  2015     12     WindDirDegrees   31   NaN
#
# [8866 rows x 5 columns]

# %%
weatherwnan=weatherm.dropna(subset='value')
weatherwnan
# Out:
#       year  month             measure  day  value
# 0     2014     12    Max.TemperatureF    1     64
# 1     2014     12   Mean.TemperatureF    1     52
# 2     2014     12    Min.TemperatureF    1     39
# 3     2014     12      Max.Dew.PointF    1     46
# 4     2014     12      MeanDew.PointF    1     40
# ...    ...    ...                 ...  ...    ...
# 8816  2015     10  Mean.Wind.SpeedMPH   31    7.0
# 8817  2015     10   Max.Gust.SpeedMPH   31   17.0
# 8818  2015     10     PrecipitationIn   31    0.0
# 8819  2015     10          CloudCover   31    4.0
# 8821  2015     10      WindDirDegrees   31  224.0
#
# [7845 rows x 5 columns]

# %%
weatherwnan['date'] = pd.to_datetime(weatherwnan[['year', 'month', 'day']])
weatherwnan = weatherwnan.drop(columns=['year', 'month', 'day'])
weatherwnan
# Out:
# <ipython-input-12-6230ab865f60>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weatherwnan['date'] = pd.to_datetime(weatherwnan[['year', 'month', 'day']])
#                  measure  value       date
# 0       Max.TemperatureF     64 2014-12-01
# 1      Mean.TemperatureF     52 2014-12-01
# 2       Min.TemperatureF     39 2014-12-01
# 3         Max.Dew.PointF     46 2014-12-01
# 4         MeanDew.PointF     40 2014-12-01
# ...                  ...    ...        ...
# 8816  Mean.Wind.SpeedMPH    7.0 2015-10-31
# 8817   Max.Gust.SpeedMPH   17.0 2015-10-31
# 8818     PrecipitationIn    0.0 2015-10-31
# 8819          CloudCover    4.0 2015-10-31
# 8821      WindDirDegrees  224.0 2015-10-31
#
# [7845 rows x 3 columns]

# %%
weatherf=weatherwnan.pivot(index='date', columns='measure', values='value')
weatherf
# Out:
# measure    CloudCover     Events Max.Dew.PointF Max.Gust.SpeedMPH  \
# date
# 2014-12-01          6       Rain             46                29
# 2014-12-02          7  Rain-Snow             40                29
# 2014-12-03          8       Rain             49                38
# 2014-12-04          3       Rain             24                33
# 2014-12-05          5       Rain             37                26
# ...               ...        ...            ...               ...
# 2015-11-27        7.0        NaN           52.0              32.0
# 2015-11-28          8       Rain             50                23
# 2015-11-29          4        NaN             33                20
# 2015-11-30          6        NaN             26                17
# 2015-12-01          7       Rain             43                17
#
# measure    Max.Humidity Max.Sea.Level.PressureIn Max.TemperatureF  \
# date
# 2014-12-01           74                    30.45               64
# ...

# %%
# Order columns with 'Temperature' first
temp_cols = [col for col in weatherf.columns if 'Temperature' in col]
other_cols = [col for col in weatherf.columns if 'Temperature' not in col]
weatherf = weatherf[temp_cols + other_cols]

# Rename columns
new_columns = []
for col in weatherf.columns:
  if 'Mean' in col:
    new_col = col.replace('Mean', 'mean')
    if 'Temperature' in col:
      new_col = 'Tmean' + col[len('Mean Temperature'):]
    new_columns.append(new_col)
  elif 'Min' in col:
    new_col = col.replace('Min', 'min')
    if 'Temperature' in col:
      new_col = 'Tmin' + col[len('Min Temperature'):]
    new_columns.append(new_col)
  elif 'Max' in col:
    new_col = col.replace('Max', 'max')
    if 'Temperature' in col:
      new_col = 'Tmax' + col[len('Max Temperature'):]
    new_columns.append(new_col)
  else:
    new_columns.append(col)

weatherf.columns = new_columns
weatherf
# Out:
#            TmaxF TmeanF TminF CloudCover     Events max.Dew.PointF  \
# date
# 2014-12-01    64     52    39          6       Rain             46
# 2014-12-02    42     38    33          7  Rain-Snow             40
# 2014-12-03    51     44    37          8       Rain             49
# 2014-12-04    43     37    30          3       Rain             24
# 2014-12-05    42     34    26          5       Rain             37
# ...          ...    ...   ...        ...        ...            ...
# 2015-11-27  64.0   56.0  48.0        7.0        NaN           52.0
# 2015-11-28    60     51    41          8       Rain             50
# 2015-11-29    44     38    32          4        NaN             33
# 2015-11-30    38     33    28          6        NaN             26
# 2015-12-01    45     39    32          7       Rain             43
#
#            max.Gust.SpeedMPH max.Humidity max.Sea.Level.PressureIn  \
# date
# 2014-12-01                29           74                    30.45
# ...

# %%
from sklearn.linear_model import LinearRegression

def predict_next_value(df, column_name, n_values):
    """
    Performs linear regression on the last n_values of a specified column
    in a DataFrame and predicts the next value.

    Args:
        df: The input DataFrame.
        column_name: The name of the column to use for prediction.
        n_values: The number of past values to use for the regression.

    Returns:
        The predicted next value.
        Returns an error message if the column does not exist or if n_values is invalid.
    """
    if column_name not in df.columns:
        return "Error: Column not found in DataFrame."

    if n_values <= 1 or n_values >= len(df):
      return "Error: Invalid number of values for regression"

    # Prepare data for linear regression
    X = np.arange(n_values).reshape(-1, 1)
    y = df[column_name].tail(n_values).values

    # Perform linear regression
    model = LinearRegression()
    model.fit(X, y)

    # Predict the next value
    next_x = n_values
    next_value = model.predict([[next_x]])[0]

    return next_value

# %%
meanT=predict_next_value(weatherf,'TmeanF',10)
maxT=predict_next_value(weatherf,'TmaxF',10)
minT=predict_next_value(weatherf,'TminF',10)
predictedval=pd.DataFrame({'TmaxF':[maxT],'TmeanF':[meanT],'TminF':[minT]})
predictedval
# Out:
#        TmaxF  TmeanF      TminF
# 0  48.533333    41.8  34.666667

# %%
plt.figure(figsize=(10, 6))
plt.plot(weatherf.index, weatherf['TmeanF'].values.astype(float), linestyle='--', label='Tmean')
plt.plot(weatherf.index, weatherf['TminF'].values.astype(float), linestyle='--', label='Tmin')
plt.plot(weatherf.index, weatherf['TmaxF'].values.astype(float), linestyle='--', label='Tmax')
plt.xlabel('Date')
plt.ylabel('F')
plt.title('Temperatures')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
